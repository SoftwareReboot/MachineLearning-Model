# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')

# %%
df = pd.read_csv("Car_Purchasing_Data.csv")

# %%
df
# Out:
#        Customer Name                                    Customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#     Country  Gender  Age  Annual Salary  Credit Card Debt    Net Worth  \
# ...

# %%
df.head()
# Out:
#      Customer Name                                    Customer e-mail Country  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu     USA
# 1    Harlan Barnes                                eu.dolor@diam.co.uk     USA
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...     USA
# 3  Jade Cunningham                            malesuada@dignissim.com     USA
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net     USA
#
#    Gender  Age  Annual Salary  Credit Card Debt    Net Worth  \
# 0       0   42    62812.09301      11609.380910  238961.2505
# 1       0   41    66646.89292       9572.957136  530973.9078
# 2       1   43    53798.55112      11160.355060  638467.1773
# 3       1   58    79370.03798      14426.164850  548599.0524
# 4       1   57    59729.15130       5358.712177  560304.0671
#
#    Car Purchase Amount
# 0          35321.45877
# 1          45115.52566
# 2          42925.70921
# 3          67422.36313
# ...

# %%
df.isnull().sum()
# Out:
# Customer Name          0
# Customer e-mail        0
# Country                0
# Gender                 0
# Age                    0
# Annual Salary          0
# Credit Card Debt       0
# Net Worth              0
# Car Purchase Amount    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Customer Name        500 non-null    object
#  1   Customer e-mail      500 non-null    object
#  2   Country              500 non-null    object
#  3   Gender               500 non-null    int64
#  4   Age                  500 non-null    int64
#  5   Annual Salary        500 non-null    float64
#  6   Credit Card Debt     500 non-null    float64
#  7   Net Worth            500 non-null    float64
#  8   Car Purchase Amount  500 non-null    float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 35.3+ KB

# %%
df.describe()
# Out:
#            Gender         Age  Annual Salary  Credit Card Debt  \
# count  500.000000  500.000000     500.000000        500.000000
# mean     0.506000   46.224000   62127.239608       9607.645049
# std      0.500465    7.990339   11703.378228       3489.187973
# min      0.000000   20.000000   20000.000000        100.000000
# 25%      0.000000   41.000000   54391.977195       7397.515792
# 50%      1.000000   46.000000   62915.497035       9655.035568
# 75%      1.000000   52.000000   70117.862005      11798.867487
# max      1.000000   70.000000  100000.000000      20000.000000
#
#             Net Worth  Car Purchase Amount
# count      500.000000           500.000000
# mean    431475.713625         44209.799218
# std     173536.756340         10773.178744
# min      20000.000000          9000.000000
# 25%     299824.195900         37629.896040
# 50%     426750.120650         43997.783390
# 75%     557324.478725         51254.709517
# max    1000000.000000         80000.000000

# %%
df = df.drop(columns=['Customer Name','Customer e-mail','Country'])

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Annual Salary', 'Credit Card Debt', 'Net Worth',
#        'Car Purchase Amount'],
#       dtype='object')

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
X = df[['Age', 'Annual Salary', 'Credit Card Debt', 'Net Worth']]  # features
y = df['Car Purchase Amount']  # target

# %%
X
# Out:
#      Age  Annual Salary  Credit Card Debt    Net Worth
# 0     42    62812.09301      11609.380910  238961.2505
# 1     41    66646.89292       9572.957136  530973.9078
# 2     43    53798.55112      11160.355060  638467.1773
# 3     58    79370.03798      14426.164850  548599.0524
# 4     57    59729.15130       5358.712177  560304.0671
# ..   ...            ...               ...          ...
# 495   41    71942.40291       6995.902524  541670.1016
# 496   38    56039.49793      12301.456790  360419.0988
# 497   54    68888.77805      10611.606860  764531.3203
# 498   59    49811.99062      14013.034510  337826.6382
# 499   47    61370.67766       9391.341628  462946.4924
#
# [500 rows x 4 columns]

# %%
y
# Out:
# 0      35321.45877
# 1      45115.52566
# 2      42925.70921
# 3      67422.36313
# 4      55915.46248
#           ...
# 495    48901.44342
# 496    31491.41457
# 497    64147.28888
# 498    45442.15353
# 499    45107.22566
# Name: Car Purchase Amount, Length: 500, dtype: float64

# %%
sns.distplot(df['Car Purchase Amount'])
# Out:
# C:\Users\Millard P. Ardines\AppData\Local\Temp\ipykernel_10140\2444207058.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Car Purchase Amount'])
# <Axes: xlabel='Car Purchase Amount', ylabel='Density'>

# %%
sns.relplot(x="Annual Salary", y="Car Purchase Amount", hue="Gender", data=df)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=10)

# %%
print("Training set", X_train.shape)
print("Testing set", X_test.shape)
# Out:
# Training set (400, 4)
# Testing set (100, 4)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# Apply scaler() to all the columns except the 'yes-no' and 'dummy' variables
numeric_features = [ 'Age', 'Annual Salary', 'Credit Card Debt', 'Net Worth']
X_train[numeric_features] = scaler.fit_transform(X_train[numeric_features])
X_test[numeric_features] = scaler.transform(X_test[numeric_features])

# %%
#Build the Classifier: import the Linear Regression library
from sklearn.linear_model import LinearRegression

# %%
#create A Linear Regression model
lm = LinearRegression()

# %%
#Train the data model
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#get the intercept
intercept = lm.intercept_

#display the Intercept
print (f"Intercept : {intercept: .2f}")
# Out:
# Intercept : -13437.80

# %%
#get the slope of each independent variable (features)

coeff_df= pd.DataFrame(lm.coef_, X.columns, columns=['Coefficient'])

# %%
#show the coefficient
print (coeff_df)
# Out:
#                    Coefficient
# Age               42041.225952
# Annual Salary     44949.096557
# Credit Card Debt     96.348805
# Net Worth         28297.508928

# %% [markdown]
# The *Linear Regression Model*: <to edit>
#
# Car Purchase Amount = -13437.80 + Age * 42041.23 + Annual Salary * 44949.10 + Credit Card Debt * 96.35 + Net Worth * 28297.51

# %% [markdown]
# Predict the total amount that customers are willing to pay for the new car using the model.

# %%
#Predict Car Purchase Amount using the training data
y_pred_train = lm.predict(X_train)
y_pred_train
# Out:
# array([40325.93755366, 34996.4746694 , 24188.99178908, 52503.94746217,
#        44276.07926572, 31360.66977584, 46032.40158986, 52202.02688149,
#        28654.71337373, 52408.59551364, 52254.10699593, 39617.2262043 ,
#        46380.1241401 , 48427.51436019, 32236.91309936, 25066.78669959,
#        37201.20257672, 60911.20878736, 56684.98524019, 67197.97267303,
#        28516.88345994, 37505.28921257, 42089.68007751, 33882.61169538,
#        47720.63984713, 40821.01274411, 48851.79238887, 24538.15564256,
#        42881.6896898 , 30735.30153586, 61093.89607775, 29499.08959258,
#        53344.76213309, 48666.61932433, 38379.98458202, 42169.99876025,
#        43683.04640571, 38859.85945973, 49093.33113636, 63983.5065382 ,
#        46916.56087305, 47535.90157905, 10150.33151606, 47908.28909061,
#        40502.39370242, 28396.58575341, 39213.11697649, 51290.08890612,
#        37134.31734442, 79920.85973925, 39260.24920201, 55204.35789252,
# ...

# %%
# Predict the car purchase amount using your own data
# Example values:
# Age = 35
# Annual Salary = 75000
# Credit Card Debt = 5000
# Net Worth = 60000

lm.predict([[35, 75000, 5000, 60000]])[0]
# Out:
# c:\Users\Millard P. Ardines\OneDrive\Desktop\AI Learnings\linear\MachineLearning-Model\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# np.float64(5070972526.615494)

# %%
# Predict on the test set
y_pred_test = lm.predict(X_test)

# Now create the comparison DataFrame
y_pred_df = pd.DataFrame({
    'Actual Car Purchase Amount': y_test,
    'Predicted Car Purchase Amount': y_pred_test,
    'Difference': y_test - y_pred_test
})

# Show first 20 rows
y_pred_df[0:20]
# Out:
#      Actual Car Purchase Amount  Predicted Car Purchase Amount  Difference
# 151                 47604.34591                   47742.507180 -138.161270
# 424                 31408.62631                   31124.628899  283.997411
# 154                 42369.64247                   42367.786973    1.855497
# 190                 56579.90338                   56384.845523  195.057857
# 131                 38243.66481                   38254.704213  -11.039403
# 310                 51866.48719                   51760.473833  106.013357
# 266                 37076.82508                   36783.121643  293.703437
# 495                 48901.44342                   48500.682861  400.760559
# 157                 38172.83602                   38603.435505 -430.599485
# 282                 32828.03477                   32959.963695 -131.928925
# 452                 45271.46081                   44862.423968  409.036842
# ...

# %%
#visualize the difference between actual and prediction results.

import matplotlib.pyplot as plt

#plt.figure(figsize=(10,10))
plt.scatter(y_train, y_pred_train, label= 'Training data',color='b', alpha=0.7)
plt.plot([min(y_train), max(y_train)], [min(y_train), max(y_train)], 'r', label='Regression line')


plt.legend()
plt.xlabel('Actual Car Purchase Amount')
plt.ylabel('Predicted Car Purchase Amount')
plt.title('Actual Price vs Predicted Price')
plt.show()

# %% [markdown]
# Evaluate the model

# %%
#r2 measures how close are the data fitted to the regression line
# r_square answers the question: Is the model is good or bad?

from sklearn.metrics import r2_score

score = r2_score(y_train,y_pred_train) # portion of the variance that can be explained by the training features
print (f"Score: {score*100: .2f}%") #coeff of determination
# Out:
# Score:  99.95%

# %%
#visualize the price using the testing versus predicted data
#plot a regression line
import seaborn as sns
sns.regplot(x=y_test,y= y_pred_test, ci=None)
#sns.regplot(x=y_test,y= y_pred_test, fit_reg=True data=data)
# Out:
# <Axes: xlabel='Car Purchase Amount'>
